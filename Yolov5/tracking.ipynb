# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = "/content/drive/My Drive/Colab Notebook/vehicles_detection/Thong_workspace"
os.chdir(path)

# %%
# !git clone https://github.com/nwojke/deep_sort.git
# Out:
# Cloning into 'deep_sort'...
# remote: Enumerating objects: 141, done.
# remote: Total 141 (delta 0), reused 0 (delta 0), pack-reused 141
# Receiving objects: 100% (141/141), 65.58 KiB | 1.60 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
work_dir = '/content/drive/.shortcut-targets-by-id/1OfcNXNsJaA-h9ulZlTkNLt-ZdvHu6-Rh/vehicles_detection/Thong_workspace/'
dataset_dir = work_dir + 'Vietnam_Vehicles_Dataset_yolov5/'
yolov5_dir = work_dir + 'Vietnam_Vehicles_Dataset_yolov5/yolov5'

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1OfcNXNsJaA-h9ulZlTkNLt-ZdvHu6-Rh/vehicles_detection/Thong_workspace
